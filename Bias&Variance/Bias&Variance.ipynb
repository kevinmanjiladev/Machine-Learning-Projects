# %% [markdown]
# ✅ Low Bias + High Variance → Overfitting
# ---
# Model is very complex
#
# Learns the training data too well (even noise)
#
# Train accuracy = high
#
# Test accuracy = low
#
# ✅ High Bias + Low Variance → Underfitting
# ---
#
# Model is too simple
#
# Cannot learn patterns
#
# Train accuracy = low
#
# Test accuracy = low
