# %% [markdown]
# 🍭 Imagine you are decorating a cake
#
# You have many toppings:
#
#     chocolates
#
#     sprinkles
#
#     fruits
#
#     cream
#
#     nuts
#
#     syrup
#
#     etc.
#
# Each topping = a feature
#
# How much you put = weight (coefficient)
#
# If you put too many toppings, the cake becomes messy → overfitting
#
# So your mom says:
#
#     “Don’t use too many toppings! Keep it simple!”
#
# This “rule” your mom gives is called regularization.

# %% [markdown]
# 🍎 L2 Regularization (Ridge)
# ---------------------------
# — Mom says: “Don’t use too much of any topping.”
#
# This rule says:
#
#     “You can use all toppings, but only little of each.
#
#     Don’t use toooo much of any one.”
#
#     So you add small amounts of each topping.
#
# 🎯 Effect in ML:
#
#     All feature weights become small
#
#     None becomes zero
#
#     Model stays smooth and simple

# %% [markdown]
# 🍩 L1 Regularization (Lasso)
# ---
#
# — Mom says: “Choose only the important toppings.”
#
# This rule says:
#
#     “Don’t use everything.
#
#     Pick only few toppings you really need.
#
#     Throw away the rest.”
#
# So you keep:
#
#     chocolates
#     sprinkles
#
# And throw away:
#
#     fruits
#     nuts
#     syrup
#     cream
#
# 🎯 Effect in ML:
#
#     Some weights become exactly zero
#
#     Unimportant features get removed
#
#     Model becomes simple and clean

# %% [markdown]
# | Regularization | Like                              | What it does            |
# | -------------- | --------------------------------- | ----------------------- |
# | **L2 (Ridge)** | “Use a little bit of everything.” | Makes weights small     |
# | **L1 (Lasso)** | “Choose only important toppings.” | Makes many weights zero |
# | **Purpose**    | “Don't make the cake messy.”      | Prevents overfitting    |

# %% [markdown]
# 🎨 Picture Explanation (Super Simple)
#
# L2 (Ridge)
#
#     → Pushes big weights to become small
#     → But never completely zero
#     → Like shrinking balloons but not popping them
#
# L1 (Lasso)
#
#     → Pushes weights so much that some become zero
#     → Like popping balloons and throwing them away

# %% [markdown]
# 🎈 Why we do this?
#
#     Because too many toppings/features → messy cake/overfitting
#     L1 and L2 help keep the model clean and simple.

# %% [markdown]
# | Use L1 When               | Use L2 When             |
# | ------------------------- | ----------------------- |
# | Need feature selection    | Want stable model       |
# | Too many useless features | All features useful     |
# | You want sparse model(many weights = 0)     | Data is noisy           |
# | Model is too slow/heavy   | You want smooth weights |
