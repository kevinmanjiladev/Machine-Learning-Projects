# %% [markdown]
# 🎯 Goal of IQR method
#
# We want a rule that tells us:
#
# How far a value must be from the center before we call it an outlier.
#
# 🎯 What is IQR?
#
# IQR is the range of the middle 50% of data.
#
# So:
#
# If a dataset is tightly packed → IQR is small
#
# If it's spread out → IQR is large
#
# 🎯 Why multiply by 1.5?
#
# Think like this 👇
#
# Suppose you are in a classroom.
#
# Half the students are between 150 cm and 170 cm
#
# So IQR = 20 cm
#
# Now, what height would be unusual?
#
# 171? → not unusual
#
# 175? → still normal
#
# 250 cm? → definitely unusual
#
# We need a boundary.
#
# If we multiply IQR by 1.5, we get:
#
# 1.5 × 20 = 30 cm
#
#
# So our boundaries become:
#
# Lower = 150 − 30 = 120 cm
#
# Upper = 170 + 30 = 200 cm
#
#
# This means:
#
# 120–200 cm → reasonable human height
#
# below 120 or above 200 → unusual (outliers)
#
# So 1.5 × IQR gives a realistic buffer.
#
# It creates a range that:
#
# is wider than the middle 50%
#
# but not so wide that everything becomes normal
