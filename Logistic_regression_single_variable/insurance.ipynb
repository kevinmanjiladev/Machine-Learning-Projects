# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df['age'],df['bought_insurance'])

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[['age']],df['bought_insurance'],test_size=0.30,random_state=42)

# %%
len(x_train)
# Out:
# 18

# %%
len(x_test)
# Out:
# 9

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([1, 0, 1, 0, 0, 0, 0, 1, 0], dtype=int64)

# %%
y_test
# Out:
# 8     1
# 13    0
# 9     1
# 21    0
# 0     0
# 11    0
# 16    1
# 17    1
# 12    0
# Name: bought_insurance, dtype: int64

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)
score=accuracy_score(y_test,y_pred)

# %%
cm
# Out:
# array([[5, 0],
#        [1, 3]], dtype=int64)

# %%
score*100
# Out:
# 88.88888888888889

# %%
model.predict_proba(x_test)
# Out:
# array([[0.04567825, 0.95432175],
#        [0.80851063, 0.19148937],
#        [0.05197447, 0.94802553],
#        [0.86384632, 0.13615368],
#        [0.91610842, 0.08389158],
#        [0.82865307, 0.17134693],
#        [0.87903892, 0.12096108],
#        [0.07611236, 0.92388764],
#        [0.8470775 , 0.1529225 ]])

# %%
x_test
# Out:
#     age
# 8    62
# 13   29
# 9    61
# 21   26
# 0    22
# 11   28
# 16   25
# 17   58
# 12   27
